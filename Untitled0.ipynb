# %% [markdown]
# <a href="https://colab.research.google.com/github/datb1910502/bt2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file .csv hoặc file .zip
df = pd.read_csv('day.csv')

# In ra vài dòng dữ liệu đầu tiên
print(df.head())

# Kiểm tra thông tin tổng quan về dữ liệu
print(df.info())

# Tính thống kê mô tả của các biến số
print(df.describe())

# Tính thống kê mô tả của các biến phân loại
print(df['season'].value_counts())  # Đếm số lượng giá trị trong biến 'season'
print(df['weathersit'].value_counts())  # Đếm số lượng giá trị trong biến 'weathersit'

# Vẽ biểu đồ histogram của biến 'temp'
import matplotlib.pyplot as plt
plt.hist(df['temp'], bins=20)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Histogram of Temperature')
plt.show()

# Vẽ biểu đồ đường của biến 'cnt' theo thời gian
plt.plot(df['dteday'], df['cnt'])
plt.xlabel('Date')
plt.ylabel('Count of Total Users')
plt.title('Count of Total Users over Time')
plt.xticks(rotation=45)
plt.show()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# ...

# %%
# Đọc dữ liệu từ file CSV
df = pd.read_csv('day.csv', encoding='ISO-8859-1')

# Xem mối quan hệ giữa các biến bằng đồ thị scatter plot
plt.scatter(df['temp'], df['hum'])
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('Scatter plot of Temperature vs Humidity')
plt.show()

# Xem mối quan hệ giữa các biến bằng đồ thị boxplot
plt.boxplot([df['registered'], df['casual']])
plt.xticks([1, 2], ['Registered', 'Casual'])
plt.ylabel('Count of Users')
plt.title('Boxplot of Registered and Casual Users')
plt.show()

# Tính hệ số tương quan giữa các biến
correlation = df[['temp', 'hum', 'registered', 'casual']].corr()
print(correlation)
# Out:
#                 temp       hum  registered    casual
# temp        1.000000  0.126963    0.540012  0.543285
# hum         0.126963  1.000000   -0.091089 -0.077008
# registered  0.540012 -0.091089    1.000000  0.395282
# casual      0.543285 -0.077008    0.395282  1.000000

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ cột cho biến 'season' và tính trung bình số lượng người dùng đăng ký (registered) theo từng mùa
season_group = df.groupby('season').mean()
plt.bar(season_group.index, season_group['registered'])
plt.xlabel('Season')
plt.ylabel('Average Registered Users')
plt.title('Average Registered Users by Season')
plt.xticks([0, 1, 2, 3], ['Spring', 'Summer', 'Fall', 'Winter'])
plt.show()

# %%
import matplotlib.pyplot as plt

# E
plt.scatter(df['temp'], df['hum'])
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('Scatter plot of Temperature vs Humidity')
plt.show()

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ hộp cho biến 'weathersit' và tính số lượng người dùng đăng ký (registered) theo từng trạng thái thời tiết
weather_group = df.groupby('weathersit').sum()
plt.boxplot([df[df['weathersit'] == 1]['registered'],
             df[df['weathersit'] == 2]['registered'],
             df[df['weathersit'] == 3]['registered']])
plt.xticks([1, 2, 3], ['Clear', 'Mist/Cloudy', 'Light Snow/Rain'])
plt.ylabel('Count of Registered Users')
plt.title('Boxplot of Registered Users by Weather Situation')
plt.show()

# %%
# Sử dụng get_dummies để chuyển các giá trị không phải số thành dạng số.
df = pd.get_dummies(df)
# Tách dữ liệu thành tập huấn luyện và tập kiểm tra, tỉ lệ 80:20.
train = df.sample(frac=0.8, random_state=123)
test = df.drop(train.index)
from sklearn.tree import DecisionTreeClassifier

# Tạo mô hình Decision Tree
model = DecisionTreeClassifier(max_depth=3)

# Huấn luyện mô hình
model.fit(train.iloc[:, :-1], train.iloc[:, -1])
from sklearn.metrics import accuracy_score

# Dự đoán trên tập kiểm tra
y_pred = model.predict(test.iloc[:, :-1])

# Tính độ chính xác của mô hình
accuracy = accuracy_score(test.iloc[:, -1], y_pred)

# In ra độ chính xác của mô hình
print("Độ chính xác của mô hình Decision Tree là:", accuracy)
# Out:
# Độ chính xác của mô hình Decision Tree là: 1.0
